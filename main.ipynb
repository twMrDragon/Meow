# %% [markdown]
# # 安裝必要依賴

# %%
! pip install pydub librosa numpy scikit-learn xgboost
# Out:
# Requirement already satisfied: pydub in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (0.25.1)
# Requirement already satisfied: librosa in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (2.1.3)
# Requirement already satisfied: scikit-learn in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (1.6.1)
# Requirement already satisfied: xgboost in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (3.0.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.61.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\joseph\appdata\roaming\python\python311\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\joseph\appdata\roaming\python\python311\site-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from librosa) (1.1.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: packaging in c:\users\joseph\appdata\roaming\python\python311\site-packages (from lazy_loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from numba>=0.51.0->librosa) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\joseph\appdata\roaming\python\python311\site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: cffi>=1.0 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joseph\appdata\local\programs\python\python311\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)
# [notice] A new release of pip is available: 23.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # MP3 轉 WAV

# %%
import os
from pydub import AudioSegment

MP3_PATH = "CAT_DB"         # 原始 mp3 資料夾
WAV_PATH = "CAT_DB_WAV"     # 轉出 wav 的資料夾

os.makedirs(WAV_PATH, exist_ok=True)

for emotion in os.listdir(MP3_PATH):
    emotion_mp3_dir = os.path.join(MP3_PATH, emotion)
    emotion_wav_dir = os.path.join(WAV_PATH, emotion)
    os.makedirs(emotion_wav_dir, exist_ok=True)

    if not os.path.isdir(emotion_mp3_dir):
        continue

    for filename in os.listdir(emotion_mp3_dir):
        if filename.endswith(".mp3"):
            mp3_file = os.path.join(emotion_mp3_dir, filename)
            wav_file = os.path.join(emotion_wav_dir, filename.replace(".mp3", ".wav"))
            print(f"轉檔中: {mp3_file} → {wav_file}")

            audio = AudioSegment.from_mp3(mp3_file)
            audio.export(wav_file, format="wav")
# Out:
# 轉檔中: CAT_DB\Angry\car_extcoll0156.mp3 → CAT_DB_WAV\Angry\car_extcoll0156.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0162.mp3 → CAT_DB_WAV\Angry\car_extcoll0162.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0169.mp3 → CAT_DB_WAV\Angry\car_extcoll0169.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0171.mp3 → CAT_DB_WAV\Angry\car_extcoll0171.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0172.mp3 → CAT_DB_WAV\Angry\car_extcoll0172.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0174.mp3 → CAT_DB_WAV\Angry\car_extcoll0174.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0175.mp3 → CAT_DB_WAV\Angry\car_extcoll0175.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0177.mp3 → CAT_DB_WAV\Angry\car_extcoll0177.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0191.mp3 → CAT_DB_WAV\Angry\car_extcoll0191.wav
# 轉檔中: CAT_DB\Angry\car_extcoll0212.mp3 → CAT_DB_WAV\Angry\car_extcoll0212.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0168.mp3 → CAT_DB_WAV\Defense\car_extcoll0168.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0180.mp3 → CAT_DB_WAV\Defense\car_extcoll0180.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0181.mp3 → CAT_DB_WAV\Defense\car_extcoll0181.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0235.mp3 → CAT_DB_WAV\Defense\car_extcoll0235.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0236.mp3 → CAT_DB_WAV\Defense\car_extcoll0236.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0251.mp3 → CAT_DB_WAV\Defense\car_extcoll0251.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0255.mp3 → CAT_DB_WAV\Defense\car_extcoll0255.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0259.mp3 → CAT_DB_WAV\Defense\car_extcoll0259.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0263.mp3 → CAT_DB_WAV\Defense\car_extcoll0263.wav
# 轉檔中: CAT_DB\Defense\car_extcoll0265.mp3 → CAT_DB_WAV\Defense\car_extcoll0265.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0160.mp3 → CAT_DB_WAV\Fighting\car_extcoll0160.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0207.mp3 → CAT_DB_WAV\Fighting\car_extcoll0207.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0208.mp3 → CAT_DB_WAV\Fighting\car_extcoll0208.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0218.mp3 → CAT_DB_WAV\Fighting\car_extcoll0218.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0222.mp3 → CAT_DB_WAV\Fighting\car_extcoll0222.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0224.mp3 → CAT_DB_WAV\Fighting\car_extcoll0224.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0232.mp3 → CAT_DB_WAV\Fighting\car_extcoll0232.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0233.mp3 → CAT_DB_WAV\Fighting\car_extcoll0233.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0234.mp3 → CAT_DB_WAV\Fighting\car_extcoll0234.wav
# 轉檔中: CAT_DB\Fighting\car_extcoll0239.mp3 → CAT_DB_WAV\Fighting\car_extcoll0239.wav
# 轉檔中: CAT_DB\Happy\cat_20.mp3 → CAT_DB_WAV\Happy\cat_20.wav
# 轉檔中: CAT_DB\Happy\cat_24.mp3 → CAT_DB_WAV\Happy\cat_24.wav
# 轉檔中: CAT_DB\Happy\cat_52.mp3 → CAT_DB_WAV\Happy\cat_52.wav
# 轉檔中: CAT_DB\Happy\cat_53.mp3 → CAT_DB_WAV\Happy\cat_53.wav
# 轉檔中: CAT_DB\Happy\cat_54.mp3 → CAT_DB_WAV\Happy\cat_54.wav
# 轉檔中: CAT_DB\Happy\cat_67.mp3 → CAT_DB_WAV\Happy\cat_67.wav
# 轉檔中: CAT_DB\Happy\cat_68.mp3 → CAT_DB_WAV\Happy\cat_68.wav
# 轉檔中: CAT_DB\Happy\cat_75.mp3 → CAT_DB_WAV\Happy\cat_75.wav
# 轉檔中: CAT_DB\Happy\cat_76.mp3 → CAT_DB_WAV\Happy\cat_76.wav
# 轉檔中: CAT_DB\Happy\cat_85.mp3 → CAT_DB_WAV\Happy\cat_85.wav
# 轉檔中: CAT_DB\HuntingMind\car_extcoll0326.mp3 → CAT_DB_WAV\HuntingMind\car_extcoll0326.wav
# 轉檔中: CAT_DB\HuntingMind\car_extcoll0327.mp3 → CAT_DB_WAV\HuntingMind\car_extcoll0327.wav
# 轉檔中: CAT_DB\HuntingMind\car_extcoll0328.mp3 → CAT_DB_WAV\HuntingMind\car_extcoll0328.wav
# 轉檔中: CAT_DB\HuntingMind\car_extcoll0329.mp3 → CAT_DB_WAV\HuntingMind\car_extcoll0329.wav
# 轉檔中: CAT_DB\HuntingMind\car_extcoll0330.mp3 → CAT_DB_WAV\HuntingMind\car_extcoll0330.wav
# 轉檔中: CAT_DB\HuntingMind\car_extcoll0331.mp3 → CAT_DB_WAV\HuntingMind\car_extcoll0331.wav
# 轉檔中: CAT_DB\HuntingMind\car_extcoll0332.mp3 → CAT_DB_WAV\HuntingMind\car_extcoll0332.wav
# 轉檔中: CAT_DB\HuntingMind\Cat_trilling0111.mp3 → CAT_DB_WAV\HuntingMind\Cat_trilling0111.wav
# 轉檔中: CAT_DB\HuntingMind\Cat_trilling0112.mp3 → CAT_DB_WAV\HuntingMind\Cat_trilling0112.wav
# 轉檔中: CAT_DB\HuntingMind\Cat_trilling0113.mp3 → CAT_DB_WAV\HuntingMind\Cat_trilling0113.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64304.mp3 → CAT_DB_WAV\Mating\cat_youtube64304.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64306.mp3 → CAT_DB_WAV\Mating\cat_youtube64306.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64307.mp3 → CAT_DB_WAV\Mating\cat_youtube64307.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64309.mp3 → CAT_DB_WAV\Mating\cat_youtube64309.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64310.mp3 → CAT_DB_WAV\Mating\cat_youtube64310.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64311.mp3 → CAT_DB_WAV\Mating\cat_youtube64311.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64312.mp3 → CAT_DB_WAV\Mating\cat_youtube64312.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64313.mp3 → CAT_DB_WAV\Mating\cat_youtube64313.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64314.mp3 → CAT_DB_WAV\Mating\cat_youtube64314.wav
# 轉檔中: CAT_DB\Mating\cat_youtube64315.mp3 → CAT_DB_WAV\Mating\cat_youtube64315.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0136.mp3 → CAT_DB_WAV\MotherCall\cat_coll0136.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0137.mp3 → CAT_DB_WAV\MotherCall\cat_coll0137.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0140.mp3 → CAT_DB_WAV\MotherCall\cat_coll0140.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0141.mp3 → CAT_DB_WAV\MotherCall\cat_coll0141.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0142.mp3 → CAT_DB_WAV\MotherCall\cat_coll0142.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll01813.mp3 → CAT_DB_WAV\MotherCall\cat_coll01813.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0183.mp3 → CAT_DB_WAV\MotherCall\cat_coll0183.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0184.mp3 → CAT_DB_WAV\MotherCall\cat_coll0184.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0185.mp3 → CAT_DB_WAV\MotherCall\cat_coll0185.wav
# 轉檔中: CAT_DB\MotherCall\cat_coll0186.mp3 → CAT_DB_WAV\MotherCall\cat_coll0186.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0146.mp3 → CAT_DB_WAV\Paining\car_extcoll0146.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0147.mp3 → CAT_DB_WAV\Paining\car_extcoll0147.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0148.mp3 → CAT_DB_WAV\Paining\car_extcoll0148.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0163.mp3 → CAT_DB_WAV\Paining\car_extcoll0163.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0187.mp3 → CAT_DB_WAV\Paining\car_extcoll0187.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0188.mp3 → CAT_DB_WAV\Paining\car_extcoll0188.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0223.mp3 → CAT_DB_WAV\Paining\car_extcoll0223.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0229.mp3 → CAT_DB_WAV\Paining\car_extcoll0229.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0247.mp3 → CAT_DB_WAV\Paining\car_extcoll0247.wav
# 轉檔中: CAT_DB\Paining\car_extcoll0336.mp3 → CAT_DB_WAV\Paining\car_extcoll0336.wav
# 轉檔中: CAT_DB\Resting\cat_coll0106.mp3 → CAT_DB_WAV\Resting\cat_coll0106.wav
# 轉檔中: CAT_DB\Resting\cat_coll0107.mp3 → CAT_DB_WAV\Resting\cat_coll0107.wav
# 轉檔中: CAT_DB\Resting\cat_coll0108.mp3 → CAT_DB_WAV\Resting\cat_coll0108.wav
# 轉檔中: CAT_DB\Resting\cat_coll0109.mp3 → CAT_DB_WAV\Resting\cat_coll0109.wav
# 轉檔中: CAT_DB\Resting\cat_coll0110.mp3 → CAT_DB_WAV\Resting\cat_coll0110.wav
# 轉檔中: CAT_DB\Resting\cat_coll0115.mp3 → CAT_DB_WAV\Resting\cat_coll0115.wav
# 轉檔中: CAT_DB\Resting\cat_coll0116.mp3 → CAT_DB_WAV\Resting\cat_coll0116.wav
# 轉檔中: CAT_DB\Resting\cat_coll0117.mp3 → CAT_DB_WAV\Resting\cat_coll0117.wav
# 轉檔中: CAT_DB\Resting\cat_coll0118.mp3 → CAT_DB_WAV\Resting\cat_coll0118.wav
# 轉檔中: CAT_DB\Resting\cat_coll0124.mp3 → CAT_DB_WAV\Resting\cat_coll0124.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0167.mp3 → CAT_DB_WAV\Warning\car_extcoll0167.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0178.mp3 → CAT_DB_WAV\Warning\car_extcoll0178.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0182.mp3 → CAT_DB_WAV\Warning\car_extcoll0182.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0185.mp3 → CAT_DB_WAV\Warning\car_extcoll0185.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0186.mp3 → CAT_DB_WAV\Warning\car_extcoll0186.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0213.mp3 → CAT_DB_WAV\Warning\car_extcoll0213.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0238.mp3 → CAT_DB_WAV\Warning\car_extcoll0238.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0239.mp3 → CAT_DB_WAV\Warning\car_extcoll0239.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0242.mp3 → CAT_DB_WAV\Warning\car_extcoll0242.wav
# 轉檔中: CAT_DB\Warning\car_extcoll0243.mp3 → CAT_DB_WAV\Warning\car_extcoll0243.wav

# %% [markdown]
# # 資料及切割和特徵擷取

# %%
import os
import librosa
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

EMOTIONS = os.listdir(WAV_PATH)

def extract_features(y, sr):
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        chroma = librosa.feature.chroma_stft(y=y, sr=sr)
        contrast = librosa.feature.spectral_contrast(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        rmse = librosa.feature.rms(y=y)
        tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(y), sr=sr)

        features = np.hstack([
            np.mean(mfcc, axis=1), np.std(mfcc, axis=1),
            np.mean(chroma, axis=1), np.std(chroma, axis=1),
            np.mean(contrast, axis=1), np.std(contrast, axis=1),
            np.mean(zcr, axis=1), np.std(zcr, axis=1),
            np.mean(rmse, axis=1), np.std(rmse, axis=1),
            np.mean(tonnetz, axis=1), np.std(tonnetz, axis=1)
        ])
        return features

def add_white_noise(y, noise_factor=0.005):
        return y + noise_factor * np.random.randn(len(y))

def pitch_shift(y, sr, n_steps):
    return librosa.effects.pitch_shift(y, sr=sr, n_steps=n_steps)

def time_stretch(y, rate):
    return librosa.effects.time_stretch(y, rate=rate)

def change_volume(y, db):
    return y * (10.0 ** (db / 20.0))

def augment_and_extract(y_raw, sr, label):
    """
    對輸入音訊進行增強並抽取特徵，回傳特徵與標籤列表。
    """
    X_aug, y_aug = [], []

    variants = [
        y_raw,
        add_white_noise(y_raw),
        pitch_shift(y_raw, sr, 2),
        pitch_shift(y_raw, sr, -2),
        time_stretch(y_raw, 1.2),
        time_stretch(y_raw, 0.8),
        change_volume(y_raw, 5),
        change_volume(y_raw, -5)
    ]

    for aug_y in variants:
        try:
            feat = extract_features(aug_y, sr)
            X_aug.append(feat)
            y_aug.append(label)
        except Exception as e:
            print(f"[!] 增強或特徵擷取失敗（{label}）: {e}")

    return X_aug, y_aug


# 特徵與標籤蒐集
X_train, y_train, X_test, y_test = [], [], [], []

for emotion in EMOTIONS:
    emotion_dir = os.path.join(WAV_PATH, emotion)
    if not os.path.isdir(emotion_dir):
        continue

    files = os.listdir(emotion_dir)
    train_files, test_files = train_test_split(
        files, test_size=0.2, random_state=42)

    for train_file in train_files:
        path = os.path.join(emotion_dir, train_file)
        y_raw, sr = librosa.load(path, sr=None)

        X_aug, y_aug = augment_and_extract(y_raw, sr, emotion)
        X_train.extend(X_aug)
        y_train.extend(y_aug)

    for test_file in test_files:
        path = os.path.join(emotion_dir, test_file)
        y_raw, sr = librosa.load(path, sr=None)

        X_aug, y_aug = augment_and_extract(y_raw, sr, emotion)
        X_test.extend(X_aug)
        y_test.extend(y_aug)


le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)
y_test_enc = le.transform(y_test)
# Out:
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=983
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1008
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=840
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=936
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=468
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=780
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=390
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=585
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=828
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=414
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=518
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=720
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=360
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=600
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=300
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=900
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=450
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=945
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=855
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=774
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=387
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=645
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=323
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=968
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=484
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=810
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=405
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=675
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=338
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1013
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=507
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=788
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=882
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=735
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=693
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=578
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=867
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=960
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=930
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=694
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=347
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=579
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=290
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=868
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=434
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=617
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=515
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=772
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=912
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=896
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=747
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=766
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=383
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=639
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=320
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=958
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=479
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=838
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=419
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=699
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=350
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=524
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=824
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=687
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=680
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=567
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=850
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=927
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=999
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=833
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=558
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=465
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=698
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=909
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=758
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=998
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=713
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=981
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=818
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=533
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=799
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=954
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=795
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1017
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=848
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=915
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=756
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=630
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=863
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=549
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=458
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=623
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=934
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1020
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=885
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=837
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=783
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=653
#   warnings.warn(
# c:\Users\Joseph\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=979
#   warnings.warn(

# %%
import xgboost as xgb
from sklearn.metrics import classification_report

# 建立 DMatrix（XGBoost 自有格式）
dtrain = xgb.DMatrix(X_train, label=y_train_enc)
dtest = xgb.DMatrix(X_test, label=y_test_enc)

params = {
    'max_depth': 8,
    'eta': 0.05,
    'objective': 'multi:softmax',
    'num_class': len(set(y_train_enc)),
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'eval_metric': 'mlogloss',
    'seed': 42,
}

evals = [(dtrain, 'train'), (dtest, 'eval')]
bst = xgb.train(params, dtrain, num_boost_round=300, evals=evals, early_stopping_rounds=20)

y_pred = bst.predict(dtest).astype(int)
print(classification_report(y_test_enc, y_pred, target_names=le.classes_))
# Out:
# [0]	train-mlogloss:2.13207	eval-mlogloss:2.22355
# [1]	train-mlogloss:1.98544	eval-mlogloss:2.16293
# [2]	train-mlogloss:1.85467	eval-mlogloss:2.09619
# [3]	train-mlogloss:1.73770	eval-mlogloss:2.04361
# [4]	train-mlogloss:1.63175	eval-mlogloss:1.98491
# [5]	train-mlogloss:1.53666	eval-mlogloss:1.94131
# [6]	train-mlogloss:1.45092	eval-mlogloss:1.90309
# [7]	train-mlogloss:1.37122	eval-mlogloss:1.86404
# [8]	train-mlogloss:1.29755	eval-mlogloss:1.82823
# [9]	train-mlogloss:1.22828	eval-mlogloss:1.78827
# [10]	train-mlogloss:1.16671	eval-mlogloss:1.75876
# [11]	train-mlogloss:1.10856	eval-mlogloss:1.72184
# [12]	train-mlogloss:1.05321	eval-mlogloss:1.69479
# [13]	train-mlogloss:1.00186	eval-mlogloss:1.67023
# [14]	train-mlogloss:0.95356	eval-mlogloss:1.64658
# [15]	train-mlogloss:0.90919	eval-mlogloss:1.62792
# [16]	train-mlogloss:0.86753	eval-mlogloss:1.60337
# [17]	train-mlogloss:0.82779	eval-mlogloss:1.57889
# [18]	train-mlogloss:0.79085	eval-mlogloss:1.55439
# [19]	train-mlogloss:0.75495	eval-mlogloss:1.53747
# [20]	train-mlogloss:0.72122	eval-mlogloss:1.52119
# [21]	train-mlogloss:0.68986	eval-mlogloss:1.50514
# [22]	train-mlogloss:0.66018	eval-mlogloss:1.48828
# [23]	train-mlogloss:0.63155	eval-mlogloss:1.47574
# [24]	train-mlogloss:0.60452	eval-mlogloss:1.45635
# [25]	train-mlogloss:0.57874	eval-mlogloss:1.43922
# [26]	train-mlogloss:0.55405	eval-mlogloss:1.42378
# [27]	train-mlogloss:0.53031	eval-mlogloss:1.40943
# [28]	train-mlogloss:0.50764	eval-mlogloss:1.39615
# [29]	train-mlogloss:0.48648	eval-mlogloss:1.38151
# [30]	train-mlogloss:0.46649	eval-mlogloss:1.36980
# [31]	train-mlogloss:0.44718	eval-mlogloss:1.35749
# [32]	train-mlogloss:0.42891	eval-mlogloss:1.34715
# [33]	train-mlogloss:0.41165	eval-mlogloss:1.33703
# [34]	train-mlogloss:0.39497	eval-mlogloss:1.32790
# [35]	train-mlogloss:0.37888	eval-mlogloss:1.31547
# [36]	train-mlogloss:0.36359	eval-mlogloss:1.30478
# [37]	train-mlogloss:0.34913	eval-mlogloss:1.29510
# [38]	train-mlogloss:0.33554	eval-mlogloss:1.28381
# [39]	train-mlogloss:0.32241	eval-mlogloss:1.27628
# [40]	train-mlogloss:0.30980	eval-mlogloss:1.26597
# [41]	train-mlogloss:0.29793	eval-mlogloss:1.25771
# [42]	train-mlogloss:0.28663	eval-mlogloss:1.24947
# [43]	train-mlogloss:0.27599	eval-mlogloss:1.24206
# [44]	train-mlogloss:0.26540	eval-mlogloss:1.23915
# [45]	train-mlogloss:0.25565	eval-mlogloss:1.23268
# [46]	train-mlogloss:0.24579	eval-mlogloss:1.22469
# [47]	train-mlogloss:0.23687	eval-mlogloss:1.21453
# [48]	train-mlogloss:0.22793	eval-mlogloss:1.20878
# [49]	train-mlogloss:0.21966	eval-mlogloss:1.20269
# [50]	train-mlogloss:0.21159	eval-mlogloss:1.19391
# [51]	train-mlogloss:0.20388	eval-mlogloss:1.18836
# [52]	train-mlogloss:0.19646	eval-mlogloss:1.18097
# [53]	train-mlogloss:0.18925	eval-mlogloss:1.17433
# [54]	train-mlogloss:0.18258	eval-mlogloss:1.16952
# [55]	train-mlogloss:0.17599	eval-mlogloss:1.16483
# [56]	train-mlogloss:0.17003	eval-mlogloss:1.16060
# [57]	train-mlogloss:0.16412	eval-mlogloss:1.15387
# [58]	train-mlogloss:0.15841	eval-mlogloss:1.14647
# [59]	train-mlogloss:0.15294	eval-mlogloss:1.14293
# [60]	train-mlogloss:0.14789	eval-mlogloss:1.13368
# [61]	train-mlogloss:0.14302	eval-mlogloss:1.12863
# [62]	train-mlogloss:0.13829	eval-mlogloss:1.12020
# [63]	train-mlogloss:0.13383	eval-mlogloss:1.11778
# [64]	train-mlogloss:0.12962	eval-mlogloss:1.11450
# [65]	train-mlogloss:0.12543	eval-mlogloss:1.11133
# [66]	train-mlogloss:0.12149	eval-mlogloss:1.10575
# [67]	train-mlogloss:0.11779	eval-mlogloss:1.10053
# [68]	train-mlogloss:0.11420	eval-mlogloss:1.09572
# [69]	train-mlogloss:0.11060	eval-mlogloss:1.09007
# [70]	train-mlogloss:0.10722	eval-mlogloss:1.08860
# [71]	train-mlogloss:0.10400	eval-mlogloss:1.08399
# [72]	train-mlogloss:0.10093	eval-mlogloss:1.08162
# [73]	train-mlogloss:0.09793	eval-mlogloss:1.08112
# [74]	train-mlogloss:0.09501	eval-mlogloss:1.08052
# [75]	train-mlogloss:0.09223	eval-mlogloss:1.07654
# [76]	train-mlogloss:0.08965	eval-mlogloss:1.07220
# [77]	train-mlogloss:0.08699	eval-mlogloss:1.07038
# [78]	train-mlogloss:0.08458	eval-mlogloss:1.06805
# [79]	train-mlogloss:0.08224	eval-mlogloss:1.06437
# [80]	train-mlogloss:0.08008	eval-mlogloss:1.06241
# [81]	train-mlogloss:0.07779	eval-mlogloss:1.06113
# [82]	train-mlogloss:0.07572	eval-mlogloss:1.05896
# [83]	train-mlogloss:0.07382	eval-mlogloss:1.05839
# [84]	train-mlogloss:0.07191	eval-mlogloss:1.05663
# [85]	train-mlogloss:0.07007	eval-mlogloss:1.05561
# [86]	train-mlogloss:0.06836	eval-mlogloss:1.05370
# [87]	train-mlogloss:0.06670	eval-mlogloss:1.05224
# [88]	train-mlogloss:0.06506	eval-mlogloss:1.04903
# [89]	train-mlogloss:0.06350	eval-mlogloss:1.04461
# [90]	train-mlogloss:0.06196	eval-mlogloss:1.04229
# [91]	train-mlogloss:0.06055	eval-mlogloss:1.04016
# [92]	train-mlogloss:0.05917	eval-mlogloss:1.03847
# [93]	train-mlogloss:0.05782	eval-mlogloss:1.03348
# [94]	train-mlogloss:0.05656	eval-mlogloss:1.02912
# [95]	train-mlogloss:0.05529	eval-mlogloss:1.02758
# [96]	train-mlogloss:0.05407	eval-mlogloss:1.02437
# [97]	train-mlogloss:0.05285	eval-mlogloss:1.02341
# [98]	train-mlogloss:0.05170	eval-mlogloss:1.02053
# [99]	train-mlogloss:0.05057	eval-mlogloss:1.01890
# [100]	train-mlogloss:0.04947	eval-mlogloss:1.01596
# [101]	train-mlogloss:0.04842	eval-mlogloss:1.01414
# [102]	train-mlogloss:0.04739	eval-mlogloss:1.00936
# [103]	train-mlogloss:0.04644	eval-mlogloss:1.00694
# [104]	train-mlogloss:0.04545	eval-mlogloss:1.00712
# [105]	train-mlogloss:0.04457	eval-mlogloss:1.00474
# [106]	train-mlogloss:0.04363	eval-mlogloss:1.00285
# [107]	train-mlogloss:0.04281	eval-mlogloss:1.00074
# [108]	train-mlogloss:0.04199	eval-mlogloss:0.99866
# [109]	train-mlogloss:0.04123	eval-mlogloss:0.99767
# [110]	train-mlogloss:0.04043	eval-mlogloss:0.99508
# [111]	train-mlogloss:0.03970	eval-mlogloss:0.99246
# [112]	train-mlogloss:0.03899	eval-mlogloss:0.99158
# [113]	train-mlogloss:0.03833	eval-mlogloss:0.99211
# [114]	train-mlogloss:0.03765	eval-mlogloss:0.99259
# [115]	train-mlogloss:0.03701	eval-mlogloss:0.99189
# [116]	train-mlogloss:0.03637	eval-mlogloss:0.99305
# [117]	train-mlogloss:0.03575	eval-mlogloss:0.99162
# [118]	train-mlogloss:0.03518	eval-mlogloss:0.99131
# [119]	train-mlogloss:0.03459	eval-mlogloss:0.98923
# [120]	train-mlogloss:0.03399	eval-mlogloss:0.98759
# [121]	train-mlogloss:0.03345	eval-mlogloss:0.98647
# [122]	train-mlogloss:0.03286	eval-mlogloss:0.98434
# [123]	train-mlogloss:0.03231	eval-mlogloss:0.98312
# [124]	train-mlogloss:0.03182	eval-mlogloss:0.98283
# [125]	train-mlogloss:0.03131	eval-mlogloss:0.98131
# [126]	train-mlogloss:0.03085	eval-mlogloss:0.98108
# [127]	train-mlogloss:0.03040	eval-mlogloss:0.98100
# [128]	train-mlogloss:0.02991	eval-mlogloss:0.98057
# [129]	train-mlogloss:0.02947	eval-mlogloss:0.98077
# [130]	train-mlogloss:0.02903	eval-mlogloss:0.98149
# [131]	train-mlogloss:0.02862	eval-mlogloss:0.98080
# [132]	train-mlogloss:0.02821	eval-mlogloss:0.97978
# [133]	train-mlogloss:0.02782	eval-mlogloss:0.97991
# [134]	train-mlogloss:0.02744	eval-mlogloss:0.97741
# [135]	train-mlogloss:0.02709	eval-mlogloss:0.97713
# [136]	train-mlogloss:0.02673	eval-mlogloss:0.97756
# [137]	train-mlogloss:0.02637	eval-mlogloss:0.97672
# [138]	train-mlogloss:0.02599	eval-mlogloss:0.97611
# [139]	train-mlogloss:0.02564	eval-mlogloss:0.97459
# [140]	train-mlogloss:0.02531	eval-mlogloss:0.97457
# [141]	train-mlogloss:0.02497	eval-mlogloss:0.97409
# [142]	train-mlogloss:0.02465	eval-mlogloss:0.97541
# [143]	train-mlogloss:0.02436	eval-mlogloss:0.97565
# [144]	train-mlogloss:0.02407	eval-mlogloss:0.97571
# [145]	train-mlogloss:0.02376	eval-mlogloss:0.97486
# [146]	train-mlogloss:0.02349	eval-mlogloss:0.97432
# [147]	train-mlogloss:0.02321	eval-mlogloss:0.97394
# [148]	train-mlogloss:0.02295	eval-mlogloss:0.97302
# [149]	train-mlogloss:0.02271	eval-mlogloss:0.97189
# [150]	train-mlogloss:0.02246	eval-mlogloss:0.97141
# [151]	train-mlogloss:0.02220	eval-mlogloss:0.96958
# [152]	train-mlogloss:0.02196	eval-mlogloss:0.96946
# [153]	train-mlogloss:0.02174	eval-mlogloss:0.96941
# [154]	train-mlogloss:0.02152	eval-mlogloss:0.96900
# [155]	train-mlogloss:0.02129	eval-mlogloss:0.96926
# [156]	train-mlogloss:0.02107	eval-mlogloss:0.96906
# [157]	train-mlogloss:0.02086	eval-mlogloss:0.96796
# [158]	train-mlogloss:0.02067	eval-mlogloss:0.96745
# [159]	train-mlogloss:0.02046	eval-mlogloss:0.96742
# [160]	train-mlogloss:0.02027	eval-mlogloss:0.96746
# [161]	train-mlogloss:0.02009	eval-mlogloss:0.96776
# [162]	train-mlogloss:0.01990	eval-mlogloss:0.96610
# [163]	train-mlogloss:0.01972	eval-mlogloss:0.96512
# [164]	train-mlogloss:0.01956	eval-mlogloss:0.96489
# [165]	train-mlogloss:0.01937	eval-mlogloss:0.96530
# [166]	train-mlogloss:0.01922	eval-mlogloss:0.96462
# [167]	train-mlogloss:0.01906	eval-mlogloss:0.96487
# [168]	train-mlogloss:0.01891	eval-mlogloss:0.96485
# [169]	train-mlogloss:0.01875	eval-mlogloss:0.96510
# [170]	train-mlogloss:0.01858	eval-mlogloss:0.96573
# [171]	train-mlogloss:0.01842	eval-mlogloss:0.96322
# [172]	train-mlogloss:0.01828	eval-mlogloss:0.96422
# [173]	train-mlogloss:0.01812	eval-mlogloss:0.96449
# [174]	train-mlogloss:0.01799	eval-mlogloss:0.96452
# [175]	train-mlogloss:0.01784	eval-mlogloss:0.96454
# [176]	train-mlogloss:0.01770	eval-mlogloss:0.96524
# [177]	train-mlogloss:0.01756	eval-mlogloss:0.96588
# [178]	train-mlogloss:0.01744	eval-mlogloss:0.96523
# [179]	train-mlogloss:0.01730	eval-mlogloss:0.96430
# [180]	train-mlogloss:0.01717	eval-mlogloss:0.96402
# [181]	train-mlogloss:0.01705	eval-mlogloss:0.96335
# [182]	train-mlogloss:0.01693	eval-mlogloss:0.96359
# [183]	train-mlogloss:0.01681	eval-mlogloss:0.96338
# [184]	train-mlogloss:0.01669	eval-mlogloss:0.96306
# [185]	train-mlogloss:0.01657	eval-mlogloss:0.96291
# [186]	train-mlogloss:0.01647	eval-mlogloss:0.96205
# [187]	train-mlogloss:0.01635	eval-mlogloss:0.96171
# [188]	train-mlogloss:0.01624	eval-mlogloss:0.96272
# [189]	train-mlogloss:0.01613	eval-mlogloss:0.96252
# [190]	train-mlogloss:0.01603	eval-mlogloss:0.96154
# [191]	train-mlogloss:0.01593	eval-mlogloss:0.96190
# [192]	train-mlogloss:0.01584	eval-mlogloss:0.96251
# [193]	train-mlogloss:0.01574	eval-mlogloss:0.96170
# [194]	train-mlogloss:0.01565	eval-mlogloss:0.96286
# [195]	train-mlogloss:0.01555	eval-mlogloss:0.96309
# [196]	train-mlogloss:0.01546	eval-mlogloss:0.96479
# [197]	train-mlogloss:0.01537	eval-mlogloss:0.96554
# [198]	train-mlogloss:0.01528	eval-mlogloss:0.96489
# [199]	train-mlogloss:0.01518	eval-mlogloss:0.96606
# [200]	train-mlogloss:0.01509	eval-mlogloss:0.96671
# [201]	train-mlogloss:0.01502	eval-mlogloss:0.96643
# [202]	train-mlogloss:0.01493	eval-mlogloss:0.96721
# [203]	train-mlogloss:0.01485	eval-mlogloss:0.96690
# [204]	train-mlogloss:0.01476	eval-mlogloss:0.96741
# [205]	train-mlogloss:0.01468	eval-mlogloss:0.96777
# [206]	train-mlogloss:0.01459	eval-mlogloss:0.96702
# [207]	train-mlogloss:0.01452	eval-mlogloss:0.96745
# [208]	train-mlogloss:0.01444	eval-mlogloss:0.96852
# [209]	train-mlogloss:0.01436	eval-mlogloss:0.96902
#               precision    recall  f1-score   support
#
#        Angry       0.00      0.00      0.00        16
#      Defense       0.80      1.00      0.89        16
#     Fighting       0.92      0.69      0.79        16
#        Happy       0.80      0.25      0.38        16
#  HuntingMind       0.72      0.81      0.76        16
#       Mating       0.88      0.94      0.91        16
#   MotherCall       0.94      1.00      0.97        16
#      Paining       0.38      0.69      0.49        16
#      Resting       0.70      1.00      0.82        16
#      Warning       0.67      0.62      0.65        16
#
#     accuracy                           0.70       160
#    macro avg       0.68      0.70      0.67       160
# weighted avg       0.68      0.70      0.67       160

# %% [markdown]
# # 模型保存

# %%
bst.save_model('model.json')

# %% [markdown]
# # 測試 youtube 抓的貓叫聲

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

bst = xgb.Booster()
bst.load_model('model.json')  # 或 'model.xgb'

test_files = ["happy_cat_1.wav", "happy_cat_2.wav","angry_cat_1.wav","angry_cat_2.wav","fighting_cat_1.wav","fighting_cat_2.wav","motherCall_cat_1.wav","motherCall_cat_2.wav"]  # 測試檔案列表
for file in test_files:
    path = os.path.join("test_wav", file)  # 假設測試檔案在 "happy" 資料夾下
    y_raw, sr = librosa.load(path, sr=None)
    x = extract_features(y_raw, sr)  # 使用之前定義的特徵提取函數
    dtest = xgb.DMatrix([x])  # 將特徵轉換為 DMatrix 格式
    pred = bst.predict(dtest)
    print(f"檔案 {file} 的預測情緒: {le.inverse_transform([int(pred[0])])[0]}")
# Out:
# 檔案 happy_cat_1.wav 的預測情緒: Paining
# 檔案 happy_cat_2.wav 的預測情緒: Paining
# 檔案 angry_cat_1.wav 的預測情緒: Mating
# 檔案 angry_cat_2.wav 的預測情緒: Paining
# 檔案 fighting_cat_1.wav 的預測情緒: Fighting
# 檔案 fighting_cat_2.wav 的預測情緒: Fighting
# 檔案 motherCall_cat_1.wav 的預測情緒: Happy
# 檔案 motherCall_cat_2.wav 的預測情緒: Happy
